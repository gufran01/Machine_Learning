# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\khang\Downloads\credit_risk_dataset (2).csv")
df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0             PERSONAL          D      35000          16.02            1
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 0                               3
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# ...                           ...
# 32576                          30
# 32577                          19
# 32578                          28
# 32579                          26
# 32580                          30
#
# [32581 rows x 12 columns]

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Getting number of (rows , columns)
df.shape
# Out:
# (32581, 12)

# %% [markdown]
# ### Checking the columns with datatypes

# %%
#Getting columns with datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %% [markdown]
# ### Checking missing values

# %%
df.isna().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              895
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
df["person_emp_length"].mean()
# Out:
# 4.789686296787225

# %%
df["person_emp_length"].median()
# Out:
# 4.0

# %%
df["loan_int_rate"].mean()
# Out:
# 11.011694892245036

# %%
df["loan_int_rate"].median()
# Out:
# 10.99

# %% [markdown]
# ### Filling NAN By Medain

# %%
df["person_emp_length"]=df["person_emp_length"].fillna(df['person_emp_length'].median())

# %%
df["person_emp_length"].isna().sum()
# Out:
# 0

# %%
df["loan_int_rate"]=df["loan_int_rate"].fillna(df["loan_int_rate"].median())

# %%
df["loan_int_rate"].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_status                   0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           32581 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               32581 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
# ### Checking the Duplicates

# %%
df.duplicated().sum()
# Out:
# 165

# %%
df[df.duplicated()]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 15975          23          42000                  RENT                5.0
# 15989          23          90000              MORTGAGE                7.0
# 15995          24          48000              MORTGAGE                4.0
# 16025          24          10000                  RENT                8.0
# 16028          23         100000              MORTGAGE                7.0
# ...           ...            ...                   ...                ...
# 32010          42          39996              MORTGAGE                2.0
# 32047          36         250000                  RENT                2.0
# 32172          49         120000              MORTGAGE               12.0
# 32259          39          40000                   OWN                4.0
# 32279          43          11340                  RENT                4.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 15975            VENTURE          B       6000           9.99            0
# 15989          EDUCATION          B       8000          10.36            0
# 15995            MEDICAL          A       4000           5.42            0
# 16025           PERSONAL          A       3000           7.90            1
# 16028          EDUCATION          A      15000           7.88            0
# ...                  ...        ...        ...            ...          ...
# 32010    HOMEIMPROVEMENT          A       2500           5.42            0
# 32047  DEBTCONSOLIDATION          A      20000           7.88            0
# 32172            MEDICAL          B      12000          10.99            0
# 32259            VENTURE          B       1000          10.37            0
# 32279          EDUCATION          C       1950          10.99            1
#
#        loan_percent_income cb_person_default_on_file  \
# 15975                 0.14                         N
# 15989                 0.09                         N
# 15995                 0.08                         N
# 16025                 0.30                         N
# 16028                 0.15                         N
# ...                    ...                       ...
# 32010                 0.06                         N
# 32047                 0.08                         N
# 32172                 0.10                         N
# 32259                 0.03                         N
# 32279                 0.17                         N
#
#        cb_person_cred_hist_length
# 15975                           4
# 15989                           3
# 15995                           4
# 16025                           3
# 16028                           4
# ...                           ...
# 32010                          12
# 32047                          17
# 32172                          12
# 32259                          16
# 32279                          11
#
# [165 rows x 12 columns]

# %% [markdown]
# ### Droping the Duplicates

# %%
#Droping the Duplicates
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (32416, 12)

# %% [markdown]
# ### Univariate Analysis
#
# **Non-Viz**
# Min
# Max
# Central tendency
# Dispersion
#
# **Viz**
# plot of Distribution - Distribution
# plot of BoxPlot - Outliers

# %% [markdown]
# ### Analysis on Age Feature

# %%
#Non_Visualization analysis
print("Minimum : ",df['person_age'].min())
print("Maxmum : ",df['person_age'].max())
print("Mean : ", df['person_age'].mean())
print("Median : ",df['person_age'].median())
print("STD : ", df['person_age'].std())
# Out:
# Minimum :  20
# Maxmum :  144
# Mean :  27.74700765054294
# Median :  26.0
# STD :  6.354099947312128

# %% [markdown]
#  --From above Person_age  column Look like mean and median are not colse, there are outlier--.

# %%
# Distribution Of person_age Feature using kde plot
df['person_age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# Detecting the outliers using boxplot
df['person_age'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# -- There are outliers in Person_age feature.

# %% [markdown]
# ### Outlier Treament
# Using 1.5 IQR rule

# %%
q3=df['person_age'].quantile(0.75)
q1=df['person_age'].quantile(0.25)
iqr=q3-q1
print("IQR : ",iqr)
lower=np.round(q1-1.5*(iqr))
print("Lower : ",lower)
upper=np.round(q3+1.5*(iqr))
print("Upper : ",upper)
# Out:
# IQR :  7.0
# Lower :  12.0
# Upper :  40.0

# %%
df[(df['person_age']>lower) & (df['person_age']<upper)]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32288          38          99996                   OWN               22.0
# 32290          37          90000              MORTGAGE               11.0
# 32292          38         200000              MORTGAGE                0.0
# 32293          38         110000              MORTGAGE                5.0
# 32294          36          92000              MORTGAGE               18.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0               PERSONAL          D      35000          16.02            1
# 1              EDUCATION          B       1000          11.14            0
# 2                MEDICAL          C       5500          12.87            1
# 3                MEDICAL          C      35000          15.23            1
# 4                MEDICAL          C      35000          14.27            1
# ...                  ...        ...        ...            ...          ...
# 32288            MEDICAL          D      25000          14.96            0
# 32290  DEBTCONSOLIDATION          A       4000           6.62            0
# 32292  DEBTCONSOLIDATION          A       3000           7.68            0
# 32293            MEDICAL          B      16000          11.99            0
# 32294  DEBTCONSOLIDATION          A       4000           7.29            0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# ...                    ...                       ...
# 32288                 0.25                         N
# 32290                 0.04                         N
# 32292                 0.01                         N
# 32293                 0.15                         N
# 32294                 0.04                         N
#
#        cb_person_cred_hist_length
# 0                               3
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# ...                           ...
# 32288                          11
# 32290                          15
# 32292                          12
# 32293                          13
# 32294                          13
#
# [30655 rows x 12 columns]

# %% [markdown]
# ### Treating outliers with map lambda function

# %%
df['person_age'].map(lambda age :upper if age >=upper else lower if age<=lower else age).isna().sum()
# Out:
# 0

# %%
df['person_age'] = df['person_age'].map(lambda age :upper if age >=upper else lower if age<=lower else age)

# %%
df['person_age'].dtypes
# Out:
# dtype('float64')

# %%
#convert the person_age Feature into integer by astype
df["person_age"]=df["person_age"].astype("int")

# %%
df['person_age'].dtypes
# Out:
# dtype('int64')

# %%
df['person_age'].value_counts()
# Out:
# 23    3861
# 22    3607
# 24    3526
# 25    3023
# 26    2462
# 27    2127
# 28    1848
# 40    1761
# 29    1682
# 30    1310
# 21    1213
# 31    1139
# 32     961
# 33     855
# 34     708
# 35     619
# 36     547
# 37     478
# 38     373
# 39     301
# 20      15
# Name: person_age, dtype: int64

# %%
df.shape
# Out:
# (32416, 12)

# %%
# checking the outliers using boxplot after Treatment..
df['person_age'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# From above Graph there are no outliers in Person_age

# %%
# Checking normal distribution for person_age Feature using QQ plot
from scipy import stats
import matplotlib.pyplot as plt
stats.probplot(df['person_age'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
# By above QQ-plot the person_age feature is not normally distributed.

# %% [markdown]
# ### Analysing Person_income  feature

# %%
#Non_Visualization analysis
print("Minimum : ",df['person_income'].min())
print("Maxmum : ",df['person_income'].max())
print("Mean : ", df['person_income'].mean())
print("Median : ",df['person_income'].median())
print("STD : ", df['person_income'].std())
# Out:
# Minimum :  4000
# Maxmum :  6000000
# Mean :  66091.64082551826
# Median :  55000.0
# STD :  62015.5802688956

# %% [markdown]
# --From above Person_income  column Look like mean and median are not colse, there are outlier--.

# %%
# Distribution Of person_income Feature using kde plot
df['person_income'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# checking the outliers using boxplot
df['person_income'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ### Outlier Treament
# Using 1.5 IQR rule

# %%
q3=df['person_income'].quantile(0.75)
q1=df['person_income'].quantile(0.25)
iqr=q3-q1
print("IQR : ",iqr)
lower_in=q1-1.5*(iqr)
print("Lower : ",lower_in)
upper_in=q3+1.5*(iqr)
print("Upper : ",upper_in)
# Out:
# IQR :  40676.0
# Lower :  -22472.0
# Upper :  140232.0

# %%
df[(df['person_income']>lower_in) & (df['person_income']<upper_in)]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32575          40          64500                  RENT                0.0
# 32576          40          53000              MORTGAGE                1.0
# 32577          40         120000              MORTGAGE                4.0
# 32578          40          76000                  RENT                3.0
# 32580          40          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0             PERSONAL          D      35000          16.02            1
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# ...                ...        ...        ...            ...          ...
# 32575        EDUCATION          B       5000          11.26            0
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# ...                    ...                       ...
# 32575                 0.08                         N
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 0                               3
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# ...                           ...
# 32575                          20
# 32576                          30
# 32577                          19
# 32578                          28
# 32580                          30
#
# [30938 rows x 12 columns]

# %%
df[df["person_income"]<lower_in]
# Out:
# Empty DataFrame
# Columns: [person_age, person_income, person_home_ownership, person_emp_length, loan_intent, loan_grade, loan_amnt, loan_int_rate, loan_status, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length]
# Index: []

# %% [markdown]
# ### Treating outliers with map lambda function

# %%
df['person_income'].map(lambda income :upper_in if income >=upper_in else lower_in if income<=lower_in else income).isna().sum()
# Out:
# 0

# %%
df["person_income"]=df['person_income'].map(lambda income :upper_in if income >=upper_in else lower_in if income<=lower_in else income)

# %%
df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22        59000.0                  RENT              123.0
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          40        53000.0              MORTGAGE                1.0
# 32577          40       120000.0              MORTGAGE                4.0
# 32578          40        76000.0                  RENT                3.0
# 32579          40       140232.0              MORTGAGE                5.0
# 32580          40        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0             PERSONAL          D      35000          16.02            1
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 0                               3
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# ...                           ...
# 32576                          30
# 32577                          19
# 32578                          28
# 32579                          26
# 32580                          30
#
# [32416 rows x 12 columns]

# %%
# checking the outliers using boxplot After outlier Treatment
df['person_income'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# From above plot, Person_income  are no outliers after doing Outlier Treatmnet

# %%
df.shape
# Out:
# (32416, 12)

# %%
# Checking normal distribution for person_income Feature using QQ plot
stats.probplot(df['person_income'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
# From QQ plot ,Person_income Feature is not a normal Distribution

# %% [markdown]
# ### Analysis on person_emp_length

# %%
#Non_Visualization analysis
print("Minimum : ",df['person_emp_length'].min())
print("Maxmum : ",df['person_emp_length'].max())
print("Mean : ", df['person_emp_length'].mean())
print("Median : ",df['person_emp_length'].median())
print("STD : ", df['person_emp_length'].std())
# Out:
# Minimum :  0.0
# Maxmum :  123.0
# Mean :  4.7688795656465945
# Median :  4.0
# STD :  4.090411377660598

# %% [markdown]
# --From above Person_emp_length  column Look like mean and median, there may outlier--.

# %%
# Distribution Of person_emo_length Feature using kde plot
df['person_emp_length'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# checking the outliers using boxplot
df['person_emp_length'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ### Outlier Treament
# Using 1.5 IQR rule

# %%
q3=df['person_emp_length'].quantile(0.75)
q1=df['person_emp_length'].quantile(0.25)
iqr=q3-q1
print("IQR : ",iqr)
lower_lg=q1-1.5*(iqr)
print("Lower : ",lower_lg)
upper_lg=q3+1.5*(iqr)
print("Upper : ",upper_lg)
# Out:
# IQR :  5.0
# Lower :  -5.5
# Upper :  14.5

# %%
df[(df['person_emp_length']>lower_lg) & (df['person_emp_length']<upper_lg)]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# 5              21         9900.0                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32576          40        53000.0              MORTGAGE                1.0
# 32577          40       120000.0              MORTGAGE                4.0
# 32578          40        76000.0                  RENT                3.0
# 32579          40       140232.0              MORTGAGE                5.0
# 32580          40        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# 5              VENTURE          A       2500           7.14            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# 5                     0.25                         N
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# 5                               2
# ...                           ...
# 32576                          30
# 32577                          19
# 32578                          28
# 32579                          26
# 32580                          30
#
# [31564 rows x 12 columns]

# %%
df[df["person_emp_length"]<lower_lg]
# Out:
# Empty DataFrame
# Columns: [person_age, person_income, person_home_ownership, person_emp_length, loan_intent, loan_grade, loan_amnt, loan_int_rate, loan_status, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length]
# Index: []

# %% [markdown]
# ### Treating outliers with map lambda function

# %%
df['person_emp_length'].map(lambda length :upper_lg if length >=upper_lg else lower_lg if length<=lower_lg else length).isna().sum()
# Out:
# 0

# %%
df['person_emp_length']=df['person_emp_length'].map(lambda length :upper_lg if length >=upper_lg else lower_lg if length<=lower_lg else length)

# %%
df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22        59000.0                  RENT               14.5
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          40        53000.0              MORTGAGE                1.0
# 32577          40       120000.0              MORTGAGE                4.0
# 32578          40        76000.0                  RENT                3.0
# 32579          40       140232.0              MORTGAGE                5.0
# 32580          40        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0             PERSONAL          D      35000          16.02            1
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 0                               3
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# ...                           ...
# 32576                          30
# 32577                          19
# 32578                          28
# 32579                          26
# 32580                          30
#
# [32416 rows x 12 columns]

# %%
df.shape
# Out:
# (32416, 12)

# %%
# checking the outliers using boxplot After Outlier Treatment
df['person_emp_length'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# from the above graph, person_emo_length as no outlier after outlier Treament

# %%
# Checking normal distribution for person_emp_length Feature using QQ plot
stats.probplot(df['person_emp_length'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
# From the above QQ plot as person_emp_length is not a Normal Distribution

# %% [markdown]
# ### Analysis on loan_amnt Feature

# %%
#Non_Visualization analysis
print("Minimum : ",df['loan_amnt'].min())
print("Maxmum : ",df['loan_amnt'].max())
print("Mean : ", df['loan_amnt'].mean())
print("Median : ",df['loan_amnt'].median())
print("STD : ", df['loan_amnt'].std())
# Out:
# Minimum :  500
# Maxmum :  35000
# Mean :  9593.845631786771
# Median :  8000.0
# STD :  6322.730240861584

# %% [markdown]
#  From above loan_amnt column Look like mean and median are not colse, there are outlier..

# %%
# Distribution Of person_emp_length Feature using kde plot
df['loan_amnt'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# checking the outliers using boxplot
df['loan_amnt'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# From above plot, there Loan_amnt feature as more Outlier

# %%
q3=df['loan_amnt'].quantile(0.75)
q1=df['loan_amnt'].quantile(0.25)
iqr=q3-q1
print("IQR : ",iqr)
lower_amt=q1-1.5*(iqr)
print("Lower : ",lower_amt)
upper_amt=q3+1.5*(iqr)
print("Upper : ",upper_amt)
# Out:
# IQR :  7250.0
# Lower :  -5875.0
# Upper :  23125.0

# %%
df[(df['loan_amnt']>lower_amt) & (df['loan_amnt']<upper_amt)]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 5              21         9900.0                   OWN                2.0
# 9              21        10000.0                   OWN                6.0
# 11             21        10000.0                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32575          40        64500.0                  RENT                0.0
# 32576          40        53000.0              MORTGAGE                1.0
# 32577          40       120000.0              MORTGAGE                4.0
# 32579          40       140232.0              MORTGAGE                5.0
# 32580          40        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 5              VENTURE          A       2500           7.14            1
# 9              VENTURE          D       1600          14.74            1
# 11     HOMEIMPROVEMENT          A       4500           8.63            1
# ...                ...        ...        ...            ...          ...
# 32575        EDUCATION          B       5000          11.26            0
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 1                     0.10                         N
# 2                     0.57                         N
# 5                     0.25                         N
# 9                     0.16                         N
# 11                    0.45                         N
# ...                    ...                       ...
# 32575                 0.08                         N
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 1                               2
# 2                               3
# 5                               2
# 9                               3
# 11                              2
# ...                           ...
# 32575                          20
# 32576                          30
# 32577                          19
# 32579                          26
# 32580                          30
#
# [30737 rows x 12 columns]

# %%
# Checking normal distribution for person_income Feature using QQ plot
stats.probplot(df['loan_amnt'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
# From the above QQ plot as Loan_amnt is not a Normal Distribution

# %% [markdown]
# ### Analysis on loan_int_rate

# %%
#Non_Visualization analysis
print("Minimum : ",df['loan_int_rate'].min())
print("Maxmum : ",df['loan_int_rate'].max())
print("Mean : ", df['loan_int_rate'].mean())
print("Median : ",df['loan_int_rate'].median())
print("STD : ", df['loan_int_rate'].std())
# Out:
# Minimum :  5.42
# Maxmum :  23.22
# Mean :  11.014661895360314
# Median :  10.99
# STD :  3.083050465962393

# %% [markdown]
# From above loan_amnt column Look like mean and median are not colse, there are outlier..

# %%
# Distribution Of loan_int_rate
Feature using kde plot
df['loan_int_rate'].plot(kind='kde')
# Out:
#   File "<ipython-input-194-1bf49b749a11>", line 2
#     Feature using kde plot
#             ^
# SyntaxError: invalid syntax

# %%
# checking the outliers using boxplot..
df['loan_int_rate'].plot(kind='box')

# %% [markdown]
#  From above loan_int_rate as outlier

# %%
q3=df['loan_int_rate'].quantile(0.75)
q1=df['loan_int_rate'].quantile(0.25)
iqr=q3-q1
print("IQR : ",iqr)
lower_rate=q1-1.5*(iqr)
print("Lower : ",lower_rate)
upper_rate=q3+1.5*(iqr)
print("Upper : ",upper_rate)

# %%
df[(df['loan_int_rate']>lower_rate) & (df['loan_int_rate']<upper_rate)]

# %% [markdown]
# ### Treating outliers with map lambda function

# %%
df['loan_int_rate'].map(lambda rate :upper_rate if rate >=upper_rate else lower_rate if rate<=lower_rate else rate).isna().sum()

# %%
df['loan_int_rate']=df['loan_int_rate'].map(lambda rate :upper_rate if rate >=upper_rate else lower_rate if rate<=lower_rate else rate)

# %%
df

# %%
df.shape

# %%
# Checking normal distribution for loa Feature using QQ plot
stats.probplot(df['loan_int_rate'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
# From the above QQ plot as Loan_int_rate is not a Normal Distribution

# %% [markdown]
# ### Analysis on loan_percent_income

# %%
#Non_Visualization analysis
print("Minimum : ",df['loan_percent_income'].min())
print("Maxmum : ",df['loan_percent_income'].max())
print("Mean : ", df['loan_percent_income'].mean())
print("Median : ",df['loan_percent_income'].median())
print("STD : ", df['loan_percent_income'].std())
# Out:
# Minimum :  0.0
# Maxmum :  0.83
# Mean :  0.1702498766041461
# Median :  0.15
# STD :  0.10681197337092514

# %%
# Distribution Of loan_percent_income Feature using kde plot
df['loan_percent_income'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# checking the outliers using boxplot..
df['loan_percent_income'].plot(kind='box')
# Out:
# <Axes: >

# %%
q1=df["loan_percent_income"].quantile(0.25)
q3=df["loan_percent_income"].quantile(0.75)
iqr=q3-q1
lower_per=q1-(1.5*iqr)
upper_per=q3+(1.5*iqr)
print(lower_per)
print(upper_per)
# Out:
# -0.12000000000000002
# 0.44000000000000006

# %%
df[(df['loan_percent_income']>lower_per) & (df['loan_percent_income']<upper_per)]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21         9600.0                   OWN                5.0
# 5              21         9900.0                   OWN                2.0
# 7              24        78956.0                  RENT                5.0
# 8              24        83000.0                  RENT                8.0
# 9              21        10000.0                   OWN                6.0
# ...           ...            ...                   ...                ...
# 32575          40        64500.0                  RENT                0.0
# 32576          40        53000.0              MORTGAGE                1.0
# 32577          40       120000.0              MORTGAGE                4.0
# 32579          40       140232.0              MORTGAGE                5.0
# 32580          40        42000.0                  RENT                2.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1       EDUCATION          B       1000          11.14            0
# 5         VENTURE          A       2500           7.14            1
# 7         MEDICAL          B      35000          11.11            1
# 8        PERSONAL          A      35000           8.90            1
# 9         VENTURE          D       1600          14.74            1
# ...           ...        ...        ...            ...          ...
# 32575   EDUCATION          B       5000          11.26            0
# 32576    PERSONAL          C       5800          13.16            0
# 32577    PERSONAL          A      17625           7.49            0
# 32579    PERSONAL          B      15000          11.48            0
# 32580     MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 1                     0.10                         N
# 5                     0.25                         N
# 7                     0.44                         N
# 8                     0.42                         N
# 9                     0.16                         N
# ...                    ...                       ...
# 32575                 0.08                         N
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 1                               2
# 5                               2
# 7                               4
# 8                               2
# 9                               3
# ...                           ...
# 32575                          20
# 32576                          30
# 32577                          19
# 32579                          26
# 32580                          30
#
# [31766 rows x 12 columns]

# %% [markdown]
# ### Treating outliers with map lambda function

# %%
df['loan_percent_income'].map(lambda loan :upper_per if loan >=upper_per else lower_per if loan<=lower_per else loan).isna().sum()
# Out:
# 0

# %%
df['loan_percent_income'] = df['loan_percent_income'].map(lambda loan :upper_per if loan >=upper_per else lower_per if loan<=lower_per else loan)

# %%
# checking the outliers using boxplot After Treatment..
df['loan_percent_income'].plot(kind='box')
# Out:
# <Axes: >

# %%
# Checking normal distribution for loa Feature using QQ plot
stats.probplot(df['loan_percent_income'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
# From the above QQ plot as Loan_person_income is not a Normal Distribution

# %% [markdown]
# ### Analysis on cb_person_cred_hist length`

# %%
#Non_Visualization analysis
print("Minimum : ",df['cb_person_cred_hist_length'].min())
print("Maxmum : ",df['cb_person_cred_hist_length'].max())
print("Mean : ", df['cb_person_cred_hist_length'].mean())
print("Median : ",df['cb_person_cred_hist_length'].median())
print("STD : ", df['cb_person_cred_hist_length'].std())
# Out:
# Minimum :  2
# Maxmum :  30
# Mean :  5.811296890424482
# Median :  4.0
# STD :  4.059030349939308

# %%
# Distribution Of loan_percent_income Feature using kde plot
df['cb_person_cred_hist_length'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# checking the outliers using boxplot..
df['cb_person_cred_hist_length'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# From the above graph , Cb_person_cred_hist_length feature as mor outlier

# %%
q1=df["cb_person_cred_hist_length"].quantile(0.25)
q3=df["cb_person_cred_hist_length"].quantile(0.75)
iqr=q3-q1
lower_cre=q1-(1.5*iqr)
upper_cre=q3+(1.5*iqr)
print(iqr)
print(lower_cre)
print(upper_cre)
# Out:
# 5.0
# -4.5
# 15.5

# %%
df[(df['cb_person_cred_hist_length']>lower_cre) & (df['cb_person_cred_hist_length']<upper_cre)]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22        59000.0                  RENT               14.5
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32290          37        90000.0              MORTGAGE               11.0
# 32292          38       140232.0              MORTGAGE                0.0
# 32293          38       110000.0              MORTGAGE                5.0
# 32294          36        92000.0              MORTGAGE               14.5
# 32295          40       101000.0              MORTGAGE                6.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0               PERSONAL          D      35000          16.02            1
# 1              EDUCATION          B       1000          11.14            0
# 2                MEDICAL          C       5500          12.87            1
# 3                MEDICAL          C      35000          15.23            1
# 4                MEDICAL          C      35000          14.27            1
# ...                  ...        ...        ...            ...          ...
# 32290  DEBTCONSOLIDATION          A       4000           6.62            0
# 32292  DEBTCONSOLIDATION          A       3000           7.68            0
# 32293            MEDICAL          B      16000          11.99            0
# 32294  DEBTCONSOLIDATION          A       4000           7.29            0
# 32295  DEBTCONSOLIDATION          F      25000          16.15            1
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.44                         Y
# 1                     0.10                         N
# 2                     0.44                         N
# 3                     0.44                         N
# 4                     0.44                         Y
# ...                    ...                       ...
# 32290                 0.04                         N
# 32292                 0.01                         N
# 32293                 0.15                         N
# 32294                 0.04                         N
# 32295                 0.25                         Y
#
#        cb_person_cred_hist_length
# 0                               3
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# ...                           ...
# 32290                          15
# 32292                          12
# 32293                          13
# 32294                          13
# 32295                          14
#
# [31277 rows x 12 columns]

# %% [markdown]
# ### Treating outliers with map lambda function

# %%
df['cb_person_cred_hist_length'].map(lambda hist :upper_cre if hist >=upper_cre else lower_cre if hist<=lower_cre else hist).isna().sum()
# Out:
# 0

# %%
df['cb_person_cred_hist_length']=df['cb_person_cred_hist_length'].map(lambda hist :upper_cre if hist >=upper_cre else lower_cre if hist<=lower_cre else hist)

# %%
df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22        59000.0                  RENT               14.5
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          40        53000.0              MORTGAGE                1.0
# 32577          40       120000.0              MORTGAGE                4.0
# 32578          40        76000.0                  RENT                3.0
# 32579          40       140232.0              MORTGAGE                5.0
# 32580          40        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0             PERSONAL          D      35000          16.02            1
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.44                         Y
# 1                     0.10                         N
# 2                     0.44                         N
# 3                     0.44                         N
# 4                     0.44                         Y
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.44                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 0                             3.0
# 1                             2.0
# 2                             3.0
# 3                             2.0
# 4                             4.0
# ...                           ...
# 32576                        15.5
# 32577                        15.5
# 32578                        15.5
# 32579                        15.5
# 32580                        15.5
#
# [32416 rows x 12 columns]

# %%
# checking the outliers using boxplot After Treatment..
df['cb_person_cred_hist_length'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
#  From the above the cb_person_cred_hist_length as no outlier After outlier Treatment

# %%
# Checking normal distribution for loa Feature using QQ plot
stats.probplot(df['cb_person_cred_hist_length'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
# From the above QQ plot as cb_person_cred_hist_length is not a Normal Distribution

# %% [markdown]
# ### Analysis on loan_status

# %%
#Non_Visualization analysis
print("Minimum : ",df['loan_status'].min())
print("Maxmum : ",df['loan_status'].max())
print("Mean : ", df['loan_status'].mean())
print("Median : ",df['loan_status'].median())
print("STD : ", df['loan_status'].std())
# Out:
# Minimum :  0
# Maxmum :  1
# Mean :  0.21868830207305034
# Median :  0.0
# STD :  0.4133630362538342

# %%
# Distribution Of loan_percent_income Feature using kde plot
df['loan_status'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# checking the outliers using boxplot..
df['loan_status'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ### Analysis on person_home_ownership

# %%
# getting value_counts()
df['person_home_ownership'].value_counts()
# Out:
# RENT        16378
# MORTGAGE    13369
# OWN          2563
# OTHER         106
# Name: person_home_ownership, dtype: int64

# %%
# getting value_counts() by normalization
df['person_home_ownership'].value_counts(normalize = True)
# Out:
# RENT        0.505244
# MORTGAGE    0.412420
# OWN         0.079066
# OTHER       0.003270
# Name: person_home_ownership, dtype: float64

# %%
# Plotting barplot for person_home_ownership feature
df['person_home_ownership'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# From the above draph Rent are more who where  apllied for loan ..

# %% [markdown]
# ### Analysis on loan_intent

# %%
# getting value_counts()
df['loan_intent'].value_counts()
# Out:
# EDUCATION            6411
# MEDICAL              6042
# VENTURE              5682
# PERSONAL             5498
# DEBTCONSOLIDATION    5189
# HOMEIMPROVEMENT      3594
# Name: loan_intent, dtype: int64

# %%
# getting value_counts() by normalization
df['loan_intent'].value_counts(normalize = True)
# Out:
# EDUCATION            0.197773
# MEDICAL              0.186389
# VENTURE              0.175284
# PERSONAL             0.169608
# DEBTCONSOLIDATION    0.160075
# HOMEIMPROVEMENT      0.110871
# Name: loan_intent, dtype: float64

# %%
# Plotting barplot for loan_intent feature
df['loan_intent'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# From above graph loan was taking more for Eductioon purpose compare to other ..

# %% [markdown]
# ### Analysis on loan_grade

# %%
# getting value_counts()
df['loan_grade'].value_counts()
# Out:
# A    10703
# B    10387
# C     6438
# D     3620
# E      963
# F      241
# G       64
# Name: loan_grade, dtype: int64

# %%
# getting value_counts() by normalization
df['loan_grade'].value_counts(normalize = True)
# Out:
# A    0.330176
# B    0.320428
# C    0.198606
# D    0.111673
# E    0.029708
# F    0.007435
# G    0.001974
# Name: loan_grade, dtype: float64

# %%
# Plotting barplot for loan_grade feature
df['loan_grade'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# from above graph we have that most of person are A grade category

# %% [markdown]
# ### Analysis on cb_person_default_on_file

# %%
# getting value_counts()
df['cb_person_default_on_file'].value_counts()
# Out:
# N    26686
# Y     5730
# Name: cb_person_default_on_file, dtype: int64

# %%
# getting value_counts() by normalization
df['cb_person_default_on_file'].value_counts(normalize = True)
# Out:
# N    0.823235
# Y    0.176765
# Name: cb_person_default_on_file, dtype: float64

# %%
# Plotting barplot for loan_intent feature
df['cb_person_default_on_file'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# ### Bi-variate Analysis Num vs Num

# %% [markdown]
# ### Analysis on Retaionship Between person_income and loan_amount

# %%
plt.scatter(x = df['person_age'],y = df['loan_status'])
plt.show()

# %% [markdown]
# From above graph there is no relationship between person_age and loan_status

# %% [markdown]
# ### Analysis the relationship between the person_income and loan_status Feature

# %%
plt.scatter(x = df['person_income'],y = df['loan_status'])
plt.show()

# %% [markdown]
# From the above graph there is no relation between the person_income and loan_status

# %% [markdown]
# ### Analysis the relationship between the person_income and loan_percent income

# %%
plt.scatter(x = df['person_income'],y = df['loan_percent_income'])
plt.show()

# %% [markdown]
# From the above, we observed that if loan amount is less then interest will be high and if the loan amount more then the interset will be low

# %% [markdown]
# ### Analysis the relationship between the person_emp_length and loan_status

# %%
plt.scatter(x = df['person_emp_length'],y = df['loan_status'])
plt.show()

# %% [markdown]
# From the above there is no relation between the person_emp_length and loan_status

# %% [markdown]
# ### Analysis_on relationship between the loan_amnt and laon_status

# %%
plt.scatter(x = df['loan_amnt'],y = df['loan_status'])
plt.show()

# %% [markdown]
#  From the above graph there is no relation between the loan_amnt and loan_status

# %% [markdown]
# ### Analysis_on relationship between the loan_int_rate and laon_status

# %%
plt.scatter(x = df['loan_int_rate'],y = df['loan_status'])
plt.show()

# %% [markdown]
# From the above graph there is no relation between the loan_amnt and loan_status

# %% [markdown]
# ### Analysis_on relationship between the cb_person_cred_hist_length and laon_status

# %%
plt.scatter(x = df['cb_person_cred_hist_length'],y = df['loan_status'])
plt.show()

# %% [markdown]
#  From the above graph there is no relation between the cb_person_cred_hist_length and loan_status

# %% [markdown]
# ### Analysis_on relationship between the person_home_ownership and laon_amnt

# %%
sns.boxplot(data=df,x=df["person_home_ownership"],y=df["loan_amnt"])
# Out:
# <Axes: xlabel='person_home_ownership', ylabel='loan_amnt'>

# %% [markdown]
# From Boxplot it states that most of the loan amount requesting by MORTGAGE Category.

# %% [markdown]
# ### Analysis on relationship between the loan_intent and loan_status

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df,x=df["loan_intent"],y=df["loan_status"])
# Out:
# <Axes: xlabel='loan_intent', ylabel='loan_status'>

# %% [markdown]
# From Barplot it states that  on an average most of the loans are sactioned for DEBTCONSOLIDATION.

# %% [markdown]
# ### Analysis on relationship B/w loan_grade and Loan_status

# %%
sns.catplot(data=df,x="loan_grade",y="loan_status",kind="bar",ci=None)

# %% [markdown]
# From Catplot(bar) it states that most of the people from G category.

# %% [markdown]
# ### Analysis on the relationship b/w laon_status and person_home_owenrship

# %%
pd.crosstab(df["loan_status"],df["person_home_ownership"]).plot(kind="bar",width=0.8,stacked=True)
# Out:
# <Axes: xlabel='loan_status'>

# %% [markdown]
#  From the plot most of the customer are renters

# %% [markdown]
# ### Analysis on relationship between the loan_status and Loan_intent

# %%
pd.crosstab(df["loan_status"],df["loan_intent"]).plot(kind="bar",width=0.8,stacked=True)
# Out:
# <Axes: xlabel='loan_status'>

# %% [markdown]
# From the plot most of Cutomer are taking for Education purpose

# %% [markdown]
# ### Analysis on relation betweeen loan_status and loan_grade

# %%
pd.crosstab(df["loan_status"],df["loan_grade"]).plot(kind="bar",width=0.8,stacked=True)
# Out:
# <Axes: xlabel='loan_status'>

# %% [markdown]
# From the above plot most of the customer are A and B category

# %% [markdown]
# ### Analysis the relatioship Between the cb_person_default and loan_status

# %%
pd.crosstab(df["loan_status"],df["cb_person_default_on_file"]).plot(kind="bar",width=0.8,stacked=True)
# Out:
# <Axes: xlabel='loan_status'>

# %% [markdown]
#  From plot  most of the loan_status are not approved

# %% [markdown]
# ### Multi_Variate Anlysis

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True,cmap="Set3",linecolor="black",linewidth=4)
# Out:
# <Axes: >

# %% [markdown]
# By using above plot,We can conclude that how strong relationship is between the Numerical Features.
# From the Numerical Features there is a strong correlation between Loan_percent_income and loan_status.

# %% [markdown]
# ### Insights and Conclusions:

# %% [markdown]
# 1)Younger borrowers may have higher default rates.
# 2)Those People with longer employment histories may be more reliable for Loan Approval.
# 3)A higher loan amount relative to income may increase the likelihood of default.
# 4)The bank should consider the length of the borrower's credit history when assessing loan applications

# %% [markdown]
# By using above plot,We can conclude that how strong relationship is between the Numerical Features.
# ==>From the Numerical Features there is a strong correlation between Loan_percent_income and loan_status.

# %% [markdown]
# **SPRINT 2 - Data Preparation and Model Building**

# %% [markdown]
# Step - 1: Load the data

# %%
df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22        59000.0                  RENT               14.5
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          40        53000.0              MORTGAGE                1.0
# 32577          40       120000.0              MORTGAGE                4.0
# 32578          40        76000.0                  RENT                3.0
# 32579          40       140232.0              MORTGAGE                5.0
# 32580          40        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0             PERSONAL          D      35000          16.02            1
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.44                         Y
# 1                     0.10                         N
# 2                     0.44                         N
# 3                     0.44                         N
# 4                     0.44                         Y
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.44                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 0                             3.0
# 1                             2.0
# 2                             3.0
# 3                             2.0
# 4                             4.0
# ...                           ...
# 32576                        15.5
# 32577                        15.5
# 32578                        15.5
# 32579                        15.5
# 32580                        15.5
#
# [32416 rows x 12 columns]

# %% [markdown]
# a. Identify the Target Variable and Splitting the Data into Train and Test

# %%
import sklearn

print(sklearn.__version__)
# Out:
# 1.2.2

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
# Identifying the inputs (X) and output (y)
X=df[['person_age', 'person_income', 'person_home_ownership',
       'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
       'loan_int_rate', 'loan_percent_income',
       'cb_person_default_on_file', 'cb_person_cred_hist_length']]
X.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22        59000.0                  RENT               14.5
# 1          21         9600.0                   OWN                5.0
# 2          25         9600.0              MORTGAGE                1.0
# 3          23        65500.0                  RENT                4.0
# 4          24        54400.0                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 0    PERSONAL          D      35000          16.02                 0.44
# 1   EDUCATION          B       1000          11.14                 0.10
# 2     MEDICAL          C       5500          12.87                 0.44
# 3     MEDICAL          C      35000          15.23                 0.44
# 4     MEDICAL          C      35000          14.27                 0.44
#
#   cb_person_default_on_file  cb_person_cred_hist_length
# 0                         Y                         3.0
# 1                         N                         2.0
# 2                         N                         3.0
# 3                         N                         2.0
# 4                         Y                         4.0

# %%
y=df['loan_status']
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: loan_status, dtype: int64

# %%
print(type(X))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
y.value_counts()
# Out:
# 0    25327
# 1     7089
# Name: loan_status, dtype: int64

# %%
# split into train and test

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state=100)

# %%
X_train.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 17995          28        60000.0                  RENT                3.0
# 14771          25       115000.0              MORTGAGE                9.0
# 31533          39       101000.0              MORTGAGE               14.5
# 4075           23        80000.0                  RENT                3.0
# 9221           23        21600.0                  RENT                5.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 17995     MEDICAL          C      25000          13.49                 0.42
# 14771    PERSONAL          A       4000           6.03                 0.03
# 31533   EDUCATION          C       2500          13.47                 0.02
# 4075    EDUCATION          D       4000          14.46                 0.05
# 9221     PERSONAL          C       5000          13.06                 0.23
#
#       cb_person_default_on_file  cb_person_cred_hist_length
# 17995                         N                        10.0
# 14771                         N                         4.0
# 31533                         Y                        15.5
# 4075                          Y                         4.0
# 9221                          Y                         4.0

# %%
print(X_train.shape, y_train.shape)

print(X_test.shape, y_test.shape)
# Out:
# (24312, 11) (24312,)
# (8104, 11) (8104,)

# %% [markdown]
# b. Separating Categorical and Numerical Columns:

# %%
X_train.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 17995          28        60000.0                  RENT                3.0
# 14771          25       115000.0              MORTGAGE                9.0
# 31533          39       101000.0              MORTGAGE               14.5
# 4075           23        80000.0                  RENT                3.0
# 9221           23        21600.0                  RENT                5.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 17995     MEDICAL          C      25000          13.49                 0.42
# 14771    PERSONAL          A       4000           6.03                 0.03
# 31533   EDUCATION          C       2500          13.47                 0.02
# 4075    EDUCATION          D       4000          14.46                 0.05
# 9221     PERSONAL          C       5000          13.06                 0.23
#
#       cb_person_default_on_file  cb_person_cred_hist_length
# 17995                         N                        10.0
# 14771                         N                         4.0
# 31533                         Y                        15.5
# 4075                          Y                         4.0
# 9221                          Y                         4.0

# %%
X_train.dtypes
# Out:
# person_age                      int64
# person_income                 float64
# person_home_ownership          object
# person_emp_length             float64
# loan_intent                    object
# loan_grade                     object
# loan_amnt                       int64
# loan_int_rate                 float64
# loan_percent_income           float64
# cb_person_default_on_file      object
# cb_person_cred_hist_length    float64
# dtype: object

# %%
X_train_cat = X_train.select_dtypes(include=['object'])

X_train_cat.head()
# Out:
#       person_home_ownership loan_intent loan_grade cb_person_default_on_file
# 17995                  RENT     MEDICAL          C                         N
# 14771              MORTGAGE    PERSONAL          A                         N
# 31533              MORTGAGE   EDUCATION          C                         Y
# 4075                   RENT   EDUCATION          D                         Y
# 9221                   RENT    PERSONAL          C                         Y

# %%
X_train_num = X_train.select_dtypes(include=['int64', 'float64'])

X_train_num.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 17995          28        60000.0                3.0      25000          13.49
# 14771          25       115000.0                9.0       4000           6.03
# 31533          39       101000.0               14.5       2500          13.47
# 4075           23        80000.0                3.0       4000          14.46
# 9221           23        21600.0                5.0       5000          13.06
#
#        loan_percent_income  cb_person_cred_hist_length
# 17995                 0.42                        10.0
# 14771                 0.03                         4.0
# 31533                 0.02                        15.5
# 4075                  0.05                         4.0
# 9221                  0.23                         4.0

# %% [markdown]
# c. Scaling the Numerical Features

# %%
X_train_num.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 17995          28        60000.0                3.0      25000          13.49
# 14771          25       115000.0                9.0       4000           6.03
# 31533          39       101000.0               14.5       2500          13.47
# 4075           23        80000.0                3.0       4000          14.46
# 9221           23        21600.0                5.0       5000          13.06
#
#        loan_percent_income  cb_person_cred_hist_length
# 17995                 0.42                        10.0
# 14771                 0.03                         4.0
# 31533                 0.02                        15.5
# 4075                  0.05                         4.0
# 9221                  0.23                         4.0

# %%
import pandas as pd

# %%
#scaling the numerical features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# column names are lost after Scaling
# (i.e. the dataframe is converted to a numpy ndarray)
X_train_num_rescaled = pd.DataFrame(scaler.fit_transform(X_train_num),
                                    columns = X_train_num.columns,
                                    index = X_train_num.index)

# %%
X_train_num_rescaled.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 17995    0.111082      -0.079282          -0.453685   2.460002       0.802472
# 14771   -0.466056       1.643664           1.159771  -0.880320      -1.610333
# 31533    2.227256       1.205096           2.638772  -1.118914       0.796004
# 4075    -0.850815       0.547244          -0.453685  -0.880320       1.116201
# 9221    -0.850815      -1.282212           0.084134  -0.721257       0.663396
#
#        loan_percent_income  cb_person_cred_hist_length
# 17995             2.462313                    1.159693
# 14771            -1.348132                   -0.461237
# 31533            -1.445836                    2.645546
# 4075             -1.152725                   -0.461237
# 9221              0.605942                   -0.461237

# %%
X_train_num.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  24312.000000   24312.000000       24312.000000  24312.000000
# mean      27.422590   62530.851267           4.687130   9534.412019
# std        5.198168   31922.723728           3.718803   6286.948816
# min       20.000000    4000.000000           0.000000    500.000000
# 25%       23.000000   38500.000000           2.000000   5000.000000
# 50%       26.000000   55000.000000           4.000000   8000.000000
# 75%       30.000000   80000.000000           7.000000  12000.000000
# max       40.000000  140232.000000          14.500000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length
# count   24312.000000         24312.000000                24312.000000
# mean       11.008887             0.167982                    5.707305
# std         3.091901             0.102352                    3.701654
# min         5.420000             0.000000                    2.000000
# 25%         8.490000             0.090000                    3.000000
# 50%        10.990000             0.150000                    4.000000
# 75%        13.160000             0.230000                    8.000000
# max        23.220000             0.440000                   15.500000

# %%
print("Number of numerical Features:",scaler.n_features_in_)

print("Mean of colummn : ", scaler.mean_)
print("STD of each columns : ", np.sqrt(scaler.var_))
# Out:
# Number of numerical Features: 7
# Mean of colummn :  [2.74225897e+01 6.25308513e+04 4.68712981e+00 9.53441202e+03
#  1.10088866e+01 1.67981655e-01 5.70730503e+00]
# STD of each columns :  [5.19806103e+00 3.19220672e+04 3.71872669e+00 6.28681952e+03
#  3.09183746e+00 1.02350232e-01 3.70157770e+00]

# %% [markdown]
# #spliting the  category data into normial and ordinal  for applying the onehot and label encoder

# %%
X_train_cat.head()
# Out:
#       person_home_ownership loan_intent loan_grade cb_person_default_on_file
# 17995                  RENT     MEDICAL          C                         N
# 14771              MORTGAGE    PERSONAL          A                         N
# 31533              MORTGAGE   EDUCATION          C                         Y
# 4075                   RENT   EDUCATION          D                         Y
# 9221                   RENT    PERSONAL          C                         Y

# %%
X_train_cat["person_home_ownership"].value_counts()
# Out:
# RENT        12297
# MORTGAGE    10032
# OWN          1899
# OTHER          84
# Name: person_home_ownership, dtype: int64

# %%
X_train_cat["loan_intent"].value_counts()
# Out:
# EDUCATION            4824
# MEDICAL              4505
# VENTURE              4253
# PERSONAL             4139
# DEBTCONSOLIDATION    3914
# HOMEIMPROVEMENT      2677
# Name: loan_intent, dtype: int64

# %%
X_train_cat["loan_grade"].value_counts()
# Out:
# A    8031
# B    7801
# C    4771
# D    2743
# E     729
# F     186
# G      51
# Name: loan_grade, dtype: int64

# %%
X_train_cat["cb_person_default_on_file"].value_counts()
# Out:
# N    20077
# Y     4235
# Name: cb_person_default_on_file, dtype: int64

# %%
X_train_cat.columns
# Out:
# Index(['person_home_ownership', 'loan_intent', 'loan_grade',
#        'cb_person_default_on_file'],
#       dtype='object')

# %%
X_train_cat_l=X_train_cat["loan_grade"]
X_train_cat_l.head()
# Out:
# 17995    C
# 14771    A
# 31533    C
# 4075     D
# 9221     C
# Name: loan_grade, dtype: object

# %%
X_train_cat_o=X_train_cat[['person_home_ownership','loan_intent','cb_person_default_on_file']]
X_train_cat_o.head()
# Out:
#       person_home_ownership loan_intent cb_person_default_on_file
# 17995                  RENT     MEDICAL                         N
# 14771              MORTGAGE    PERSONAL                         N
# 31533              MORTGAGE   EDUCATION                         Y
# 4075                   RENT   EDUCATION                         Y
# 9221                   RENT    PERSONAL                         Y

# %% [markdown]
# Applying OneHotEncoding on person_home_ownership , loan_intent & cb_person_default_on_fiel Categorical columns

# %%
X_train_cat_o['person_home_ownership'].value_counts(normalize =True)
# Out:
# RENT        0.505800
# MORTGAGE    0.412636
# OWN         0.078110
# OTHER       0.003455
# Name: person_home_ownership, dtype: float64

# %%
X_train_cat_o['cb_person_default_on_file'].value_counts(normalize =True)
# Out:
# N    0.825806
# Y    0.174194
# Name: cb_person_default_on_file, dtype: float64

# %%
X_train_cat_o['loan_intent'].value_counts(normalize =True)
# Out:
# EDUCATION            0.198421
# MEDICAL              0.185299
# VENTURE              0.174934
# PERSONAL             0.170245
# DEBTCONSOLIDATION    0.160990
# HOMEIMPROVEMENT      0.110110
# Name: loan_intent, dtype: float64

# %%
# OneHotEncoding the categorical features
from sklearn.preprocessing import OneHotEncoder
encoder_ = OneHotEncoder(drop='first', sparse=False)

X_train_cat_ohe = pd.DataFrame(encoder_.fit_transform(X_train_cat_o),
                               columns=encoder_.get_feature_names_out(X_train_cat_o.columns),
                               index = X_train_cat_o.index)

X_train_cat_ohe.head()
# Out:
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 17995                          0.0                        0.0
# 14771                          0.0                        0.0
# 31533                          0.0                        0.0
# 4075                           0.0                        0.0
# 9221                           0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 17995                         1.0                    0.0
# 14771                         0.0                    0.0
# 31533                         0.0                    1.0
# 4075                          1.0                    1.0
# 9221                          1.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 17995                          0.0                  1.0                   0.0
# 14771                          0.0                  0.0                   1.0
# 31533                          0.0                  0.0                   0.0
# 4075                           0.0                  0.0                   0.0
# 9221                           0.0                  0.0                   1.0
#
#        loan_intent_VENTURE  cb_person_default_on_file_Y
# 17995                  0.0                          0.0
# 14771                  0.0                          0.0
# 31533                  0.0                          1.0
# 4075                   0.0                          1.0
# 9221                   0.0                          1.0

# %%
encoder_.categories_
# Out:
# [array(['MORTGAGE', 'OTHER', 'OWN', 'RENT'], dtype=object),
#  array(['DEBTCONSOLIDATION', 'EDUCATION', 'HOMEIMPROVEMENT', 'MEDICAL',
#         'PERSONAL', 'VENTURE'], dtype=object),
#  array(['N', 'Y'], dtype=object)]

# %%
X_train_cat_ohe.shape
# Out:
# (24312, 9)

# %% [markdown]
# e. Applying Label Encoding on loan_grade Categorical Columns

# %%
X_train_cat_le = pd.DataFrame(index=X_train_cat.index)

X_train_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [17995, 14771, 31533, 4075, 9221]

# %%
X_train_cat_l.unique()
# Out:
# array(['C', 'A', 'D', 'E', 'B', 'F', 'G'], dtype=object)

# %%
X_train_cat_l
# Out:
# 17995    C
# 14771    A
# 31533    C
# 4075     D
# 9221     C
#         ..
# 12119    A
# 24545    B
# 14147    A
# 23442    C
# 5640     B
# Name: loan_grade, Length: 24312, dtype: object

# %%
grade_encoder = {'A':7 ,'B': 6 ,'C':5 ,'D' : 4,'E' : 3 , 'F' :2, 'G' :1}
X_train_cat_le['loan_grade'] = X_train_cat['loan_grade'].apply(lambda x : grade_encoder[x])

# %%
grade_encoder
# Out:
# {'A': 7, 'B': 6, 'C': 5, 'D': 4, 'E': 3, 'F': 2, 'G': 1}

# %%
X_train_cat_le.head()
# Out:
#        loan_grade
# 17995           5
# 14771           7
# 31533           5
# 4075            4
# 9221            5

# %%
X_train_cat_le.value_counts()
# Out:
# loan_grade
# 7             8031
# 6             7801
# 5             4771
# 4             2743
# 3              729
# 2              186
# 1               51
# dtype: int64

# %% [markdown]
# Concatinating the OneHotEncoder and Label Feature of Catageroy

# %%
X_train_cat_transformed=pd.concat([X_train_cat_ohe,X_train_cat_le],axis=1)

# %%
X_train_cat_transformed.head()
# Out:
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 17995                          0.0                        0.0
# 14771                          0.0                        0.0
# 31533                          0.0                        0.0
# 4075                           0.0                        0.0
# 9221                           0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 17995                         1.0                    0.0
# 14771                         0.0                    0.0
# 31533                         0.0                    1.0
# 4075                          1.0                    1.0
# 9221                          1.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 17995                          0.0                  1.0                   0.0
# 14771                          0.0                  0.0                   1.0
# 31533                          0.0                  0.0                   0.0
# 4075                           0.0                  0.0                   0.0
# 9221                           0.0                  0.0                   1.0
#
#        loan_intent_VENTURE  cb_person_default_on_file_Y  loan_grade
# 17995                  0.0                          0.0           5
# 14771                  0.0                          0.0           7
# 31533                  0.0                          1.0           5
# 4075                   0.0                          1.0           4
# 9221                   0.0                          1.0           5

# %%
X_train_cat_transformed.shape
# Out:
# (24312, 10)

# %% [markdown]
# Concatinating the numerical and categorical columns

# %%
X_train_transformed=pd.concat([X_train_cat_transformed,X_train_num_rescaled],axis=1)

# %%
X_train_transformed.head()
# Out:
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 17995                          0.0                        0.0
# 14771                          0.0                        0.0
# 31533                          0.0                        0.0
# 4075                           0.0                        0.0
# 9221                           0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 17995                         1.0                    0.0
# 14771                         0.0                    0.0
# 31533                         0.0                    1.0
# 4075                          1.0                    1.0
# 9221                          1.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 17995                          0.0                  1.0                   0.0
# 14771                          0.0                  0.0                   1.0
# 31533                          0.0                  0.0                   0.0
# 4075                           0.0                  0.0                   0.0
# 9221                           0.0                  0.0                   1.0
#
#        loan_intent_VENTURE  cb_person_default_on_file_Y  loan_grade  \
# 17995                  0.0                          0.0           5
# 14771                  0.0                          0.0           7
# 31533                  0.0                          1.0           5
# 4075                   0.0                          1.0           4
# 9221                   0.0                          1.0           5
#
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 17995    0.111082      -0.079282          -0.453685   2.460002       0.802472
# 14771   -0.466056       1.643664           1.159771  -0.880320      -1.610333
# 31533    2.227256       1.205096           2.638772  -1.118914       0.796004
# 4075    -0.850815       0.547244          -0.453685  -0.880320       1.116201
# 9221    -0.850815      -1.282212           0.084134  -0.721257       0.663396
#
#        loan_percent_income  cb_person_cred_hist_length
# 17995             2.462313                    1.159693
# 14771            -1.348132                   -0.461237
# 31533            -1.445836                    2.645546
# 4075             -1.152725                   -0.461237
# 9221              0.605942                   -0.461237

# %%
X_train_transformed.shape
# Out:
# (24312, 17)

# %% [markdown]
# Data perparation on Test Data

# %%
X_test.shape
# Out:
# (8104, 11)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8104 entries, 25666 to 27616
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  8104 non-null   int64
#  1   person_income               8104 non-null   float64
#  2   person_home_ownership       8104 non-null   object
#  3   person_emp_length           8104 non-null   float64
#  4   loan_intent                 8104 non-null   object
#  5   loan_grade                  8104 non-null   object
#  6   loan_amnt                   8104 non-null   int64
#  7   loan_int_rate               8104 non-null   float64
#  8   loan_percent_income         8104 non-null   float64
#  9   cb_person_default_on_file   8104 non-null   object
#  10  cb_person_cred_hist_length  8104 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 759.8+ KB

# %% [markdown]
# Separating Categorical and numerical columns

# %%
X_test_cat=X_test.select_dtypes(include=['object'])

# %%
X_test_cat.head()
# Out:
#       person_home_ownership      loan_intent loan_grade  \
# 25666                  RENT  HOMEIMPROVEMENT          B
# 18151              MORTGAGE         PERSONAL          C
# 24159              MORTGAGE          MEDICAL          A
# 57                      OWN         PERSONAL          A
# 9770                   RENT          MEDICAL          C
#
#       cb_person_default_on_file
# 25666                         N
# 18151                         Y
# 24159                         N
# 57                            N
# 9770                          N

# %%
X_test_cat.shape
# Out:
# (8104, 4)

# %% [markdown]
# Separating the numerical columns

# %%
X_test_num=X_test.select_dtypes(include=['int64','float64'])

# %%
X_test_num.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 25666          33       110000.0                3.0      12000          10.65
# 18151          31       140232.0               14.5      10000          13.49
# 24159          31        70000.0                4.0      12000           6.91
# 57             23       140232.0                3.0      35000          10.99
# 9770           22        25920.0                1.0       9000          10.59
#
#        loan_percent_income  cb_person_cred_hist_length
# 25666                 0.11                         5.0
# 18151                 0.06                         8.0
# 24159                 0.17                         7.0
# 57                    0.13                         4.0
# 9770                  0.35                         2.0

# %%
X_test_num.shape
# Out:
# (8104, 7)

# %% [markdown]
# Scaling the numerical test data

# %%
X_test_num_rescaled = pd.DataFrame(scaler.transform(X_test_num),
                                    columns = X_test_num.columns,
                                    index = X_test_num.index)

X_test_num_rescaled.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 25666    1.072979       1.487032          -0.453685   0.392184      -0.116075
# 18151    0.688220       2.434089           2.638772   0.074058       0.802472
# 24159    0.688220       0.233981          -0.184776   0.392184      -1.325712
# 57      -0.850815       2.434089          -0.453685   4.050631      -0.006109
# 9770    -1.043195      -1.146882          -0.991503  -0.085005      -0.135481
#
#        loan_percent_income  cb_person_cred_hist_length
# 25666            -0.566502                   -0.191082
# 18151            -1.055021                    0.619383
# 24159             0.019720                    0.349228
# 57               -0.371095                   -0.461237
# 9770              1.778387                   -1.001547

# %% [markdown]
# Applying the OneEncoder on nomial Categorical columns

# %%
X_test_cat.columns
# Out:
# Index(['person_home_ownership', 'loan_intent', 'loan_grade',
#        'cb_person_default_on_file'],
#       dtype='object')

# %%
X_test_cat['cb_person_default_on_file'].value_counts()
# Out:
# N    6609
# Y    1495
# Name: cb_person_default_on_file, dtype: int64

# %%
X_test_cat['loan_intent'].value_counts()
# Out:
# EDUCATION            1587
# MEDICAL              1537
# VENTURE              1429
# PERSONAL             1359
# DEBTCONSOLIDATION    1275
# HOMEIMPROVEMENT       917
# Name: loan_intent, dtype: int64

# %%
X_test_cat['loan_grade'].value_counts()
# Out:
# A    2672
# B    2586
# C    1667
# D     877
# E     234
# F      55
# G      13
# Name: loan_grade, dtype: int64

# %%
X_test_cat['person_home_ownership'].value_counts()
# Out:
# RENT        4081
# MORTGAGE    3337
# OWN          664
# OTHER         22
# Name: person_home_ownership, dtype: int64

# %%
X_test_cat_o=X_test_cat[['person_home_ownership','loan_intent','cb_person_default_on_file']]

# %%
X_test_cat_o.head()
# Out:
#       person_home_ownership      loan_intent cb_person_default_on_file
# 25666                  RENT  HOMEIMPROVEMENT                         N
# 18151              MORTGAGE         PERSONAL                         Y
# 24159              MORTGAGE          MEDICAL                         N
# 57                      OWN         PERSONAL                         N
# 9770                   RENT          MEDICAL                         N

# %%
encoder_
# Out:
# OneHotEncoder(drop='first', sparse=False, sparse_output=False)

# %%
X_test_cat_ohe = pd.DataFrame(encoder_.transform(X_test_cat_o),
                             columns = encoder_.get_feature_names_out(X_test_cat_o.columns),
                             index = X_test_cat_o.index)

# %%
X_test_cat_ohe.head()
# Out:
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 25666                          0.0                        0.0
# 18151                          0.0                        0.0
# 24159                          0.0                        0.0
# 57                             0.0                        1.0
# 9770                           0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 25666                         1.0                    0.0
# 18151                         0.0                    0.0
# 24159                         0.0                    0.0
# 57                            0.0                    0.0
# 9770                          1.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 25666                          1.0                  0.0                   0.0
# 18151                          0.0                  0.0                   1.0
# 24159                          0.0                  1.0                   0.0
# 57                             0.0                  0.0                   1.0
# 9770                           0.0                  1.0                   0.0
#
#        loan_intent_VENTURE  cb_person_default_on_file_Y
# 25666                  0.0                          0.0
# 18151                  0.0                          1.0
# 24159                  0.0                          0.0
# 57                     0.0                          0.0
# 9770                   0.0                          0.0

# %%
X_test_cat_ohe.shape
# Out:
# (8104, 9)

# %% [markdown]
# Applying the LabelEncoder on ordinal Categorical columns

# %%
X_test_cat_le=pd.DataFrame(index=X_test_cat.index)

# %%
X_test_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [25666, 18151, 24159, 57, 9770]

# %%
X_test_cat['loan_grade'].unique()
# Out:
# array(['B', 'C', 'A', 'D', 'E', 'F', 'G'], dtype=object)

# %%
grade_encoder
# Out:
# {'A': 7, 'B': 6, 'C': 5, 'D': 4, 'E': 3, 'F': 2, 'G': 1}

# %%
X_test_cat_le['loan_grade'] = X_test_cat["loan_grade"].apply(lambda x : grade_encoder[x])
X_test_cat_le.head()
# Out:
#        loan_grade
# 25666           6
# 18151           5
# 24159           7
# 57              7
# 9770            5

# %%
X_test_cat_le.shape
# Out:
# (8104, 1)

# %% [markdown]
# Concatinting Nominal Categorical and ordinal  Categorical Features

# %%
X_test_cat_transformed = pd.concat([X_test_cat_ohe,X_test_cat_le],axis=1)

# %%
X_test_cat_transformed.head()
# Out:
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 25666                          0.0                        0.0
# 18151                          0.0                        0.0
# 24159                          0.0                        0.0
# 57                             0.0                        1.0
# 9770                           0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 25666                         1.0                    0.0
# 18151                         0.0                    0.0
# 24159                         0.0                    0.0
# 57                            0.0                    0.0
# 9770                          1.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 25666                          1.0                  0.0                   0.0
# 18151                          0.0                  0.0                   1.0
# 24159                          0.0                  1.0                   0.0
# 57                             0.0                  0.0                   1.0
# 9770                           0.0                  1.0                   0.0
#
#        loan_intent_VENTURE  cb_person_default_on_file_Y  loan_grade
# 25666                  0.0                          0.0           6
# 18151                  0.0                          1.0           5
# 24159                  0.0                          0.0           7
# 57                     0.0                          0.0           7
# 9770                   0.0                          0.0           5

# %%
X_test_cat_transformed.shape
# Out:
# (8104, 10)

# %% [markdown]
# Concatininting the categorical transfromed  and numerical rescaling data

# %%
X_test_transformed = pd.concat([X_test_cat_transformed,X_test_num_rescaled],axis=1)

# %%
X_test_transformed.head()
# Out:
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 25666                          0.0                        0.0
# 18151                          0.0                        0.0
# 24159                          0.0                        0.0
# 57                             0.0                        1.0
# 9770                           0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 25666                         1.0                    0.0
# 18151                         0.0                    0.0
# 24159                         0.0                    0.0
# 57                            0.0                    0.0
# 9770                          1.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 25666                          1.0                  0.0                   0.0
# 18151                          0.0                  0.0                   1.0
# 24159                          0.0                  1.0                   0.0
# 57                             0.0                  0.0                   1.0
# 9770                           0.0                  1.0                   0.0
#
#        loan_intent_VENTURE  cb_person_default_on_file_Y  loan_grade  \
# 25666                  0.0                          0.0           6
# 18151                  0.0                          1.0           5
# 24159                  0.0                          0.0           7
# 57                     0.0                          0.0           7
# 9770                   0.0                          0.0           5
#
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 25666    1.072979       1.487032          -0.453685   0.392184      -0.116075
# 18151    0.688220       2.434089           2.638772   0.074058       0.802472
# 24159    0.688220       0.233981          -0.184776   0.392184      -1.325712
# 57      -0.850815       2.434089          -0.453685   4.050631      -0.006109
# 9770    -1.043195      -1.146882          -0.991503  -0.085005      -0.135481
#
#        loan_percent_income  cb_person_cred_hist_length
# 25666            -0.566502                   -0.191082
# 18151            -1.055021                    0.619383
# 24159             0.019720                    0.349228
# 57               -0.371095                   -0.461237
# 9770              1.778387                   -1.001547

# %%
X_test_transformed.shape
# Out:
# (8104, 17)

# %% [markdown]
# Step5-Model Building

# %% [markdown]
# KNN Classifier Model

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train_transformed,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Step-6 Predicting the Model

# %%
y_test_pred=knn.predict(X_test_transformed)

# %%
temp_df=pd.DataFrame({'Actual' : y_test ,'prediction' : y_test_pred})

# %%
temp_df.head()
# Out:
#        Actual  prediction
# 25666       0           0
# 18151       0           0
# 24159       0           0
# 57          0           0
# 9770        1           1

# %% [markdown]
# Step -7 Evaluating

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,y_test_pred)
# Out:
# 0.883390918065153

# %% [markdown]
# Plotting the Graph for KNN classiffier

# %%
sns.histplot(y_test,color='blue',alpha=0.5)
sns.histplot(y_test_pred,color='red',alpha=0.5)
# Out:
# <Axes: xlabel='loan_status', ylabel='Count'>

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logistic=LogisticRegression()
logistic.fit(X_train_transformed,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Predicting the Model

# %%
y_test_pred=logistic.predict(X_test_transformed)

# %%
temp_df= pd.DataFrame({'Actual value' : y_test,'Predicted value ' : y_test_pred})
temp_df.head()
# Out:
#        Actual value  Predicted value
# 25666             0                 0
# 18151             0                 0
# 24159             0                 0
# 57                0                 0
# 9770              1                 1

# %% [markdown]
# Step -7 Evaluating

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,y_test_pred)
# Out:
# 0.8499506416584403

# %% [markdown]
# Plotting the Graph for Logistic Regression

# %%
sns.histplot(y_test,color='blue',alpha=0.5)
sns.histplot(y_test_pred,color='red',alpha=0.5)
# Out:
# <Axes: xlabel='loan_status', ylabel='Count'>

# %% [markdown]
# - Support Vector Machines

# %%
from  sklearn.svm import SVC
svc = SVC()
svc.fit(X_train_transformed,y_train)
# Out:
# SVC()

# %% [markdown]
# Prediciting the Model

# %%
y_test_pred = svc.predict(X_test_transformed)

# %%
temp_df= pd.DataFrame({'Actual value' : y_test,'Predicted value ' : y_test_pred})
temp_df.head()
# Out:
#        Actual value  Predicted value
# 25666             0                 0
# 18151             0                 0
# 24159             0                 0
# 57                0                 0
# 9770              1                 1

# %% [markdown]
# Evaluating the model

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,y_test_pred)
# Out:
# 0.8920286278381047

# %% [markdown]
# Plotting the Graph for - Support Vector Machines

# %%
sns.histplot(y_test,color='blue',alpha=0.5)
sns.histplot(y_test_pred,color='red',alpha=0.5)
# Out:
# <Axes: xlabel='loan_status', ylabel='Count'>

# %% [markdown]
# - Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree.fit(X_train_transformed,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Prediciting the Model

# %%
y_test_pred=tree.predict(X_test_transformed)

# %%
temp_df= pd.DataFrame({'Actual value' : y_test,'Predicted value ' : y_test_pred})
temp_df.head()
# Out:
#        Actual value  Predicted value
# 25666             0                 0
# 18151             0                 0
# 24159             0                 0
# 57                0                 0
# 9770              1                 1

# %% [markdown]
# Evaluating the model

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,y_test_pred)
# Out:
# 0.8893139190523198

# %% [markdown]
# Plotting the Graph for - DecisionTreeClassifier

# %%
sns.histplot(y_test,color='blue',alpha=0.5)
sns.histplot(y_test_pred,color='red',alpha=0.5)
# Out:
# <Axes: xlabel='loan_status', ylabel='Count'>

# %% [markdown]
# - Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(X_train_transformed,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# Prediciting the Model

# %%
y_test_pred=rfc.predict(X_test_transformed)

# %% [markdown]
# Evaluating the model

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,y_test_pred)
# Out:
# 0.9304047384007897

# %% [markdown]
# Plotting the Graph for - - Random Forest

# %%
sns.histplot(y_test,color='blue',alpha=0.5)
sns.histplot(y_test_pred,color='red',alpha=0.5)
# Out:
# <Axes: xlabel='loan_status', ylabel='Count'>

# %% [markdown]
# ### **Conculsion**

# %% [markdown]
# In summary, while all the evaluated models demonstrated strong predictive performance with accuracies above 80%, the RandomForest Classifier emerged as the best model for predicting loan approval, achieving an exceptional accuracy of 93%. Its superior performance, robustness, and ability to provide actionable insights into feature importance make it the most reliable and effective choice for this task. Implementing the RandomForest Classifier in the loan approval process will enhance decision-making accuracy, reduce financial risks, and improve overall operational efficiency.
